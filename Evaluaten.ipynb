# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn
import math


# Load the MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Reshape the dataset to have a single color channel
x_train_normalized = x_train.reshape((60000, 28, 28, 1))
x_test_normalized = x_test.reshape((10000, 28, 28, 1))

# Normalize the dataset
x_train, x_test = x_train / 255.0, x_test / 255.0
# Out:
# WARNING:tensorflow:From C:\Users\sd021\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 9
#       5 import math
#       8 # Load the MNIST dataset
# ----> 9 (x_train, y_train), (x_test, y_test) = mnist.load_data()
#      11 # Reshape the dataset to have a single color channel
#      12 x_train_normalized = x_train.reshape((60000, 28, 28, 1))
#
# NameError: name 'mnist' is not defined

# %%
# load a saved marvin configuration you want to evaluate
model_name = './saved_model/MarvinTest'
model_reloaded = tf.keras.models.load_model(model_name)

loss, acc = model_reloaded.evaluate(x_test, y_test, verbose=2)
print('Restored model, accuracy: {:5.2f}%'.format(100 * acc))
#print('Restored model, loss: {:5.2f}%'.format(100 * loss))

# %%
# Let the model predict on the test set, so we have some data to evaluate his performance.
predictions = marvin_reloaded.predict([x_test])

# Remember that the prediction of model is a probability distribution over all ten-digit classes
# We want him to assign the digit class with the highest probability to the sample.
predictions = np.argmax(predictions, axis=1)
#pd.DataFrame(predictions)

# %%
# Plot the accuracy and loss over epochs
plt.figure(figsize=(12, 6))

# Accuracy
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')

# Loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')

plt.show()

# %%
# Plot for the intuitive approach

numbers_to_display = 196
num_cells = math.ceil(math.sqrt(numbers_to_display))
plt.figure(figsize=(15, 15))

for plot_index in range(numbers_to_display):    
    predicted_label = predictions[plot_index]
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    color_map = 'Greens' if predicted_label == y_test[plot_index] else 'Reds'
    plt.subplot(num_cells, num_cells, plot_index + 1)
    plt.imshow(x_test_normalized[plot_index].reshape((28, 28)), cmap=color_map)
    plt.xlabel(predicted_label)

plt.subplots_adjust(hspace=1, wspace=0.5)
plt.show()

# %%
print(classification_report(y_test, predictions)
# Out:
#   Cell In[38], line 1
#     print(classification_report(y_test, predictions)
#                                                     ^
# SyntaxError: incomplete input

# %%
confusion_matrix = tf.math.confusion_matrix(y_test, predictions)

f, ax = plt.subplots(figsize=(9, 7))
sn.heatmap(
    confusion_matrix,
    annot=True,
    linewidths=.7,
    fmt="d",
    square=True,
    ax=ax,
    cmap="viridis",
)
plt.show()
